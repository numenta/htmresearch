% %% [markdown]
% # Octave Scripts and Results

% %%
setenv GNUTERM svg

% %% [markdown]
% ## Description
%
% This repository contains scripts that demonstrates presence of high-order cell assemblies from wide-field calcium imaging data. This is a collabo.pngrative project with[ Prof. Spencer Smith](http://slslab.org/) and Dr. Yiyi Yu from University of North Carolina, Chapel Hill. Part of the results has been presented at [the 3rd International Conference on Mathematical Neuroscience](https://www.math.uh.edu/~zpkilpat/icmns2017/index.html). The conference submission and presentation can be found in `icmns_submission`

% %% [markdown]
% ## Data preprocessing
% Run the script [combine_datasets.m](./combine_datasets.m) to pre-process the data. The data should be stored in the [data/](./data) directory. Each directory contains a different experiment. For each experiment, there are simultaneous recording from the primary visual cortex (V1, Combo3_V1.mat) and a higher visual cortex (area AL, Combo3_AL.mat).
%
% These files can be opened via Matlab, or using the [mat4py library](https://pypi.python.org/pypi/mat4py/0.1.0).

% %%
source('combine_datasets.m')

% %% [markdown]
% ## Decrease sparsity over trials
% Run the script [sparsity_over_trial.m](./sparsity_over_trial.m) to see the decreasing sparsity across repeated trials. You can change the `area` variable to see the result for `V1` or `AL`. The summary plots will be saved in [figures/sparsity/](./figures/sparsity). Below is an example result for area AL.

% %%
source('sparsity_over_trial.m')
% Out:
% Number of cells: 352
% Number of cells: 375
% Number of cells: 147
% Number of cells: 226
% Number of cells: 375
% Number of cells: 590
% Number of cells: 189

% %% [markdown]
% ## Presence of high-order cell assemblies
%
% Run the script [analyze_data_populaiton.m](./analyze_data_populaiton.m) to see evidence of high-order cell assemblies. The script will generate the following result for each experiment session
%
% * sparsity over trial (figures/sparseness_over_time_stim_*, Fig. 1C)
% * subset index calculation (figures/subset_index_stim_* Fig. 1D)
% * Number of unique high-order cell assemblies (cellAssembly_* Fig. 1E)
% * Accuracy of cell assembly occurance time (cellAssembly_jitter_*, Fig. 1F)
% * Example raster plots (figures/exampleRaster_Stim_* slide #27)

% %%
pkg load statistics
pkg load dataframe
source('analyze_data_populaiton.m')
% Out:
% Number of cells: 352
%  num binary words: 351
%  mean frequency : 51.0171
%  max frequency : 276
%  num binary words: 39119
%  mean frequency : 1.0464
%  max frequency : 6
%  num binary words: 19497
%  mean frequency : 1.024
%  max frequency : 4
%  num binary words: 39119
%  mean frequency : 1.0464
%  max frequency : 6
%  num binary words: 18668
%  mean frequency : 1.0213
%  max frequency : 4
%  num binary words: 12790
%  mean frequency : 1.0879
%  max frequency : 4
%  num binary words: 19450
%  mean frequency : 1.021
%  max frequency : 4
%  num binary words: 12678
%  mean frequency : 1.0312
%  max frequency : 4
%  num binary words: 18952
%  mean frequency : 1.026
%  max frequency : 5
%  num binary words: 13210
%  mean frequency : 1.0442
%  max frequency : 3
%  1.0464
%  1.0260
%  1.0442
%  num binary words: 52207
%  mean frequency : 1.0046
%  max frequency : 3
%  num binary words: 16169
%  mean frequency : 1.0037
%  max frequency : 4
%  num binary words: 6882
%  mean frequency : 1.0003
%  max frequency : 2
%  num binary words: 16131
%  mean frequency : 1.0027
%  max frequency : 2
%  num binary words: 6394
%  mean frequency : 1.0013
%  max frequency : 2
%  num binary words: 15377
%  mean frequency : 1.0028
%  max frequency : 2
%  num binary words: 6579
%  mean frequency : 1.0003
%  max frequency : 2
%  1.0046
%  1.0028
%  1.0003
%  num binary words: 60537
%  mean frequency : 1.0003
%  max frequency : 2
%  num binary words: 10576
%  mean frequency : 1.0003
%  max frequency : 2
%  num binary words: 3119
%  mean frequency : 1
%  max frequency : 1
%  num binary words: 12670
%  mean frequency : 1.0002
%  max frequency : 2
%  num binary words: 2753
%  mean frequency : 1
%  max frequency : 1
%  num binary words: 11357
%  mean frequency : 1.0002
%  max frequency : 2
%  num binary words: 2223
%  mean frequency : 1
%  max frequency : 1
%  1.0003
%  1.0002
%  1
%  num binary words: 61826
%  mean frequency : 1
%  max frequency : 1
%  num binary words: 4814
%  mean frequency : 1
%  max frequency : 1
%  num binary words: 1074
%  mean frequency : 1
%  max frequency : 1
%  num binary words: 9939
%  mean frequency : 1.0002
%  max frequency : 2
%  num binary words: 1115
%  mean frequency : 1
%  max frequency : 1
%  num binary words: 6278
%  mean frequency : 1
%  max frequency : 1
%  num binary words: 895
%  mean frequency : 1
%  max frequency : 1
%  1
%  1
%  1
