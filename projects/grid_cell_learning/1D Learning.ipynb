# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook

from CAN import CAN1DNetwork
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
dt = 0.03
network = CAN1DNetwork(200,
                       200,
                       .015,
                       dt = dt,
                       decayConstant=.03,
                       globalTonicMagnitude = 0,
                       constantTonicMagnitude = 0,
                       stdpWindow = 0.1/dt)

# %%
network.learn(100)
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-eee07746f266> in <module>()
# ----> 1 network.learn(100)
#
# /Users/mschwarzer/nta/htmresearch/projects/grid_cell_learning/CAN.py in learn(self, time)
#     346     # Carry out any hanging STDP updates.
#     347     self.stdpUpdate(clearBuffer=True)
# --> 348
#     349
#     350   def normalize_weights(self, IINorm, IENorm, EINorm):
#
# /Users/mschwarzer/nta/htmresearch/projects/grid_cell_learning/CAN.py in plotActivation(self, position)
#     395   def stdpUpdate(self, clearBuffer=False):
#     396     """
# --> 397     Adds the current activations to the tracking queue, and then performs an
#     398     STDP update if possible.
#     399     :return: Nothing.  All changes made in-place.
#
# ...

# %%
plt.matshow(network.weightsII, cmap=plt.cm.coolwarm)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="480">

# %%
codeI = np.random.random_sample((200,))
codeE = np.random.random_sample((200,))

network.simulate(5, codeI, codeE, 0, dt = 0.0001)
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-7ab05a19f46e> in <module>()
#       2 codeE = np.random.random_sample((200,))
#       3
# ----> 4 network.simulate(5, codeI, codeE, 0, dt = 0.0001)
#
# /Users/mschwarzer/nta/htmresearch/projects/grid_cell_learning/CAN.pyc in simulate(self, time, feedforwardInputI, feedforwardInputE, v, recurrent, dt)
#     240       self.update(feedforwardInputI, feedforwardInputE, v, recurrent, True)
#     241       if i % 10 == 0:
# --> 242         self.plotActivation()
#     243
#     244     self.dt = oldDt
#
# /Users/mschwarzer/nta/htmresearch/projects/grid_cell_learning/CAN.pyc in plotActivation(self, position)
#     376
#     377   def plotActivation(self, position = None):
# --> 378     self.ax1.clear()
#     379     x = np.arange(0, len(self.activationsER), 1)
# ...
